# %%
# !pip install ultralytics

# %%
# !pip install numpy matplotlib --no-cache-dir --force-reinstall

# %%
# %%writefile data.yaml
# # Set the absolute root path to your dataset on Kaggle
# path: /kaggle/input/bestset/dataset
#
# # Relative paths from the 'path' above
# train: /kaggle/input/bestset/dataset/train/images
# val: /kaggle/input/bestset/dataset/val/images
#
# # Number of classes
# nc: 3
# names: ['Mask_Worn_Correctly','Not_Wearing_Mask', 'Mask_Worn_Incorrectly']
# Out:
# Writing data.yaml

# %%
with open('/kaggle/working/data.yaml', 'r') as f:
    content = f.read()
    print(content)
# Out:
# # Set the absolute root path to your dataset on Kaggle
# path: /kaggle/input/bestset/dataset
#
# # Relative paths from the 'path' above
# train: /kaggle/input/bestset/dataset/train/images
# val: /kaggle/input/bestset/dataset/val/images
#
# # Number of classes
# nc: 3
# names: ['Mask_Worn_Correctly','Not_Wearing_Mask', 'Mask_Worn_Incorrectly']

# %%
from ultralytics import YOLO

# Load a pretrained YOLO11n model
model = YOLO("yolo11n.pt")

# Train the model on the mask dataset for 200 epochs
train_results = model.train(
    data="/kaggle/working/data.yaml",  # Path to dataset configuration file
    epochs=150,  # Number of training epochs
    imgsz=640,  # Image size for training
    device=[0, 1],  # Device to run on (e.g., 'cpu', 0, [0,1,2,3])
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.219 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#                                                        CUDA:1 (Tesla T4, 15095MiB)
# ...

# %%
# Evaluate the model's performance on the validation set
metrics = model.val()
# Out:
# Ultralytics 8.3.219 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 631.7±235.4 MB/s, size: 430.1 KB)
# val: Scanning /kaggle/input/bestset/dataset/val/labels... 171 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 171/171 602.5it/s 0.3s0.2s
# WARNING ⚠️ val: Cache directory /kaggle/input/bestset/dataset/val is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 3.2it/s 3.4s0.1s
#                    all        171        755       0.92      0.813      0.872      0.612
#    Mask_Worn_Correctly        155        619      0.947      0.918      0.957      0.697
#       Not_Wearing_Mask         52        117      0.883      0.821      0.871      0.584
#  Mask_Worn_Incorrectly         16         19       0.93        0.7      0.788      0.556
# ...

# %%
# Export the model to ONNX format for deployment
path = model.export(format="onnx")  # Returns the path to the exported model
# Out:
# Ultralytics 8.3.219 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon CPU @ 2.00GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
#
# PyTorch: starting from '/kaggle/working/runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 7, 8400) (5.2 MB)
# requirements: Ultralytics requirements ['onnxslim>=0.1.71', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
#
# requirements: AutoUpdate success ✅ 4.2s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.18.0 opset 19...
# ONNX: slimming with onnxslim 0.1.71...
# ONNX: export success ✅ 5.8s, saved as '/kaggle/working/runs/detect/train/weights/best.onnx' (10.1 MB)
#
# Export complete (6.1s)
# Results saved to /kaggle/working/runs/detect/train/weights
# ...

# %%
# !zip -r runs.zip /kaggle/working/runs
# Out:
#   adding: kaggle/working/runs/ (stored 0%)
#   adding: kaggle/working/runs/detect/ (stored 0%)
#   adding: kaggle/working/runs/detect/train/ (stored 0%)
#   adding: kaggle/working/runs/detect/train/train_batch0.jpg (deflated 8%)
#   adding: kaggle/working/runs/detect/train/val_batch1_pred.jpg (deflated 5%)
#   adding: kaggle/working/runs/detect/train/train_batch6022.jpg (deflated 14%)
#   adding: kaggle/working/runs/detect/train/val_batch0_labels.jpg (deflated 5%)
#   adding: kaggle/working/runs/detect/train/confusion_matrix_normalized.png (deflated 22%)
#   adding: kaggle/working/runs/detect/train/BoxP_curve.png (deflated 12%)
#   adding: kaggle/working/runs/detect/train/confusion_matrix.png (deflated 25%)
#   adding: kaggle/working/runs/detect/train/train_batch1.jpg (deflated 6%)
#   adding: kaggle/working/runs/detect/train/val_batch2_labels.jpg (deflated 6%)
#   adding: kaggle/working/runs/detect/train/train_batch2.jpg (deflated 6%)
# ...
